    cap_rmse[idx, :] = np.array(trail[3])
    cap_mae[idx, :] = np.array(trail[4])
    cap_mape[idx, :] = np.array(trail[5])
    life_rmse[idx, :] = np.array(trail[6])
    life_mae[idx, :] = np.array(trail[7])
    life_mape[idx, :] = np.array(trail[8])

print(f"training time, median:{np.median(training_time)}, std: {training_time.std()}")
print(f"eval time, median: {np.median(eval_time)}, std: {eval_time.std()}")
print(f"cap_rmse, median:{np.median(cap_rmse, axis=0)}, std: {cap_rmse.std(axis=0)}")
print(f"cap_mae, median: {np.median(cap_mae, axis=0)}, std: {cap_mae.std(axis=0)}")
print(f"cap_mape, median: {np.median(cap_mape, axis=0)}, std: {cap_mape.std(axis=0)}")
print(f"life_rmse, median: {np.median(life_rmse, axis=0)}, std: {life_rmse.std(axis=0)}")
print(f"life_mae, median: {np.median(life_mae, axis=0)}, std: {life_mae.std(axis=0)}")
print(f"life_mape, median: {np.median(life_mape, axis=0)}, std: {life_mape.std(axis=0)}")
# Out:
# training time, median:20.950217843055725, std: 0.9671159725245262
# eval time, median: 0.17866122722625732, std: 0.07985098468758915
# cap_rmse, median:[0.03382111 0.03566818 0.04902083 0.06868339], std: [0.00280272 0.00216646 0.00483928 0.00324601]
# cap_mae, median: [0.02538921 0.02624216 0.03660286 0.04706176], std: [0.00249331 0.00199696 0.00355677 0.00318934]
# cap_mape, median: [2.56574874 2.6490182  3.67338159 5.80811222], std: [0.24873063 0.19505269 0.36001983 0.27448296]
# life_rmse, median: [ 92.15284818 195.32350845 198.62734255 134.88821366], std: [6.50506577 6.50694802 9.43588469 7.72998774]
# life_mae, median: [ 70.66428493  98.55356545 138.32052718 104.18297074], std: [5.94354938 9.38032851 4.88272691 6.21041863]
# life_mape, median: [11.01097684 12.71602421 12.21465404 13.21174119], std: [0.98335935 1.46786536 0.38298231 0.74515594]

# %%
len(results)
# Out:
# 10

# %% [markdown]
# ### delta QV 100-10

# %%
results = [('trail #4', 56.293628215789795, 0.35372376441955566, [0.034380283671005145, 0.03205267306935898, 0.051526143171999016, 0.06090180184917118], [0.024941158686232943, 0.02376264332643281, 0.038148976733036764, 0.04055506856921362], [2.5270739867371845, 2.395930954263715, 3.838568767510432, 5.275026371147966], [128.15874895308482, 141.61170534346294, 246.3154212141163, 78.52676217552049], [89.00223140564749, 98.61306094599425, 150.22861910335627, 58.209373059933505], [14.170626670938255, 13.5722643030508, 12.48197340636545, 7.294270588087063]), ('trail #5', 59.44164323806763, 0.8032152652740479, [0.031482781594741195, 0.030128560936984825, 0.04699261989327754, 0.06061048181163775], [0.022489264644619453, 0.02190831422512709, 0.034841104778979816, 0.03856327576252215], [2.2793277551791835, 2.214129096377699, 3.5025100782986858, 5.1699648760464], [128.28785436172421, 141.01716118857564, 236.49813101778108, 77.09903638936483], [90.15035198061605, 103.29913891247907, 146.7561186938018, 61.71126240068634], [14.55549521240738, 14.663718324931473, 12.347246798403418, 7.960315
444], [13.5954982783427, 13.577591655361063, 12.119755749253326, 7.280436707051627]), ('trail #9', 65.47978448867798, 0.1986863613128662, [0.03191830459457883, 0.030365218232812283, 0.052984002445067555, 0.06111500385246538], [0.02299683532993354, 0.022389368457312892, 0.039200931429206824, 0.042775994199611284], [2.325772276581206, 2.2571548988303927, 3.9450372413038752, 5.323378121874729], [121.23523090221838, 136.59600193122174, 249.30319452380962, 90.29863815973349], [85.54089734409905, 97.41079140899409, 149.81525504945012, 64.86516012846265], [13.831955336111179, 13.660711581508497, 12.32343579978, 7.813547999133337]), ('trail #8', 67.31202626228333, 0.10220742225646973, [0.03223938919145166, 0.03049890611471374, 0.050111294466699555, 0.06002719476555336], [0.02307136214742092, 0.022283888391725615, 0.03697229776242346, 0.03956638801253322], [2.3393453450910764, 2.251263522223529, 3.7219669553976957, 5.17517841511608], [125.63796463766681, 139.66708576542015, 243.06249987857632, 76.08232059528125], [88.75679778856514, 101.75926213171029, 149.23179682522806, 58.31131596546074], [14.387141257474667, 14.321765071819904, 12.492964922385019, 7.345669564287428])]

# %%
import numpy as np
num_trials = len(results)
num_datasets = 4
training_time, eval_time = np.full(num_trials, np.nan), np.full(num_trials, np.nan)
cap_rmse, cap_mae, cap_mape = np.full((num_trials, num_datasets), np.nan), \
                              np.full((num_trials, num_datasets), np.nan), \
                              np.full((num_trials, num_datasets), np.nan)
life_rmse, life_mae, life_mape = np.full((num_trials, num_datasets), np.nan), \
                                 np.full((num_trials, num_datasets), np.nan), \
                                 np.full((num_trials, num_datasets), np.nan)

for idx, trail in enumerate(results):
    training_time[idx], eval_time[idx] = trail[1], trail[2]
    cap_rmse[idx, :] = np.array(trail[3])
    cap_mae[idx, :] = np.array(trail[4])
    cap_mape[idx, :] = np.array(trail[5])
    life_rmse[idx, :] = np.array(trail[6])
    life_mae[idx, :] = np.array(trail[7])
    life_mape[idx, :] = np.array(trail[8])

print(f"training time, median:{np.median(training_time)}, std: {training_time.std()}")
print(f"eval time, median: {np.median(eval_time)}, std: {eval_time.std()}")
print(f"cap_rmse, median:{np.median(cap_rmse, axis=0)}, std: {cap_rmse.std(axis=0)}")
print(f"cap_mae, median: {np.median(cap_mae, axis=0)}, std: {cap_mae.std(axis=0)}")
print(f"cap_mape, median: {np.median(cap_mape, axis=0)}, std: {cap_mape.std(axis=0)}")
print(f"life_rmse, median: {np.median(life_rmse, axis=0)}, std: {life_rmse.std(axis=0)}")
print(f"life_mae, median: {np.median(life_mae, axis=0)}, std: {life_mae.std(axis=0)}")
print(f"life_mape, median: {np.median(life_mape, axis=0)}, std: {life_mape.std(axis=0)}")
# Out:
# training time, median:64.28046524524689, std: 3.381820660178257
# eval time, median: 0.24768805503845215, std: 0.1841402789432864
# cap_rmse, median:[0.0317342  0.03002681 0.04736593 0.06058901], std: [0.00104644 0.00090054 0.00320877 0.00039408]
# cap_mae, median: [0.02269913 0.021834   0.0351084  0.03939294], std: [0.00090663 0.00083276 0.00236107 0.00125113]
                              np.full((num_trials, num_datasets), np.nan), \
                              np.full((num_trials, num_datasets), np.nan)
life_rmse, life_mae, life_mape = np.full((num_trials, num_datasets), np.nan), \
                                 np.full((num_trials, num_datasets), np.nan), \
                                 np.full((num_trials, num_datasets), np.nan)
trail_idxs = np.full(num_trials, np.nan)
for idx, trail in enumerate(results):
    trail_idxs[idx] = int(trail[0].split("#")[-1])
    training_time[idx], eval_time[idx] = trail[1], trail[2]
    cap_rmse[idx, :] = np.array(trail[3])
    cap_mae[idx, :] = np.array(trail[4])
    cap_mape[idx, :] = np.array(trail[5])
    life_rmse[idx, :] = np.array(trail[6])
    life_mae[idx, :] = np.array(trail[7])
    life_mape[idx, :] = np.array(trail[8])

print(f"training time, median:{np.median(training_time)}, std: {training_time.std()}")
print(f"eval time, median: {np.median(eval_time)}, std: {eval_time.std()}")
print(f"cap_rmse, median:{np.median(cap_rmse, axis=0)}, std: {cap_rmse.std(axis=0)}")
print(f"cap_mae, median: {np.median(cap_mae, axis=0)}, std: {cap_mae.std(axis=0)}")
print(f"cap_mape, median: {np.median(cap_mape, axis=0)}, std: {cap_mape.std(axis=0)}")
print(f"life_rmse, median: {np.median(life_rmse, axis=0)}, std: {life_rmse.std(axis=0)}")
print(f"life_mae, median: {np.median(life_mae, axis=0)}, std: {life_mae.std(axis=0)}")
print(f"life_mape, median: {np.median(life_mape, axis=0)}, std: {life_mape.std(axis=0)}")
# Out:
# training time, median:46.75646162033081, std: 2.9715513908817353
# eval time, median: 0.233381986618042, std: 0.08582654926175586
# cap_rmse, median:[0.0312932  0.02974474 0.04578102 0.0605916 ], std: [0.00104485 0.00112465 0.00465804 0.0005355 ]
# cap_mae, median: [0.02237944 0.02161288 0.03396739 0.03935306], std: [0.00099304 0.00115215 0.00351799 0.00138526]
# cap_mape, median: [2.26725885 2.18428701 3.41407339 5.21066267], std: [0.09564279 0.11108956 0.35447612 0.05176374]
# life_rmse, median: [126.68312312 137.40085622 235.15433027  79.73220255], std: [6.26072626 5.73443955 8.34773936 6.72641667]
# life_mae, median: [ 88.87226019 102.2084608  146.82524258  62.15605716], std: [6.34862104 5.47067499 1.94453916 6.24955978]
# life_mape, median: [14.45681127 14.47703915 12.40397638  7.6560304 ], std: [1.08103848 1.12332399 0.45495836 0.96110307]

# %%
trail_idxs
# Out:
# array([5., 4., 1., 8., 0., 2., 9., 3., 6., 7.])

# %%
cap_mae_all_data = cap_mae.mean(axis=1)
life_mape_all_data = life_mape.mean(axis=1)

# %%
np.argsort(life_mape_all_data)[len(life_mape_all_data)//2]
# Out:
# 7

# %%
cap_mae_all_data
# Out:
# array([0.02952529, 0.03064484, 0.02745614, 0.02905675, 0.03123097,
#        0.03070226, 0.02563813, 0.02854886, 0.03126349, 0.02851262])

# %%
life_mape_all_data
# Out:
# array([12.53126734, 12.02220904, 13.58971597, 12.45389903, 11.92002494,
#        11.694075  , 14.34900416, 12.42424935, 11.31501242, 12.17227612])
