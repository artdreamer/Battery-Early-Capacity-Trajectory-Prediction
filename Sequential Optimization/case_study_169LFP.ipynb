                                 np.full((num_trials, num_datasets), np.nan)

for idx, trail in enumerate(results):
    training_time[idx], eval_time[idx] = trail[1], trail[2]
    cap_rmse[idx, :] = np.array(trail[3])
    cap_mae[idx, :] = np.array(trail[4])
    cap_mape[idx, :] = np.array(trail[5])
    life_rmse[idx, :] = np.array(trail[6])
    life_mae[idx, :] = np.array(trail[7])
    life_mape[idx, :] = np.array(trail[8])

print(f"training time, median:{np.median(training_time)}, std: {training_time.std()}")
print(f"eval time, median: {np.median(eval_time)}, std: {eval_time.std()}")
print(f"cap_rmse, median:{np.median(cap_rmse, axis=0)}, std: {cap_rmse.std(axis=0)}")
print(f"cap_mae, median: {np.median(cap_mae, axis=0)}, std: {cap_mae.std(axis=0)}")
print(f"cap_mape, median: {np.median(cap_mape, axis=0)}, std: {cap_mape.std(axis=0)}")
print(f"life_rmse, median: {np.median(life_rmse, axis=0)}, std: {life_rmse.std(axis=0)}")
print(f"life_mae, median: {np.median(life_mae, axis=0)}, std: {life_mae.std(axis=0)}")
print(f"life_mape, median: {np.median(life_mape, axis=0)}, std: {life_mape.std(axis=0)}")
# Out:
# training time, median:21.507113456726074, std: 0.7540842552292759
# eval time, median: 0.1413125991821289, std: 0.03181810451607149
# cap_rmse, median:[0.08176781 0.0419694  0.10661609 0.10585674], std: [0.01308422 0.00437017 0.02215477 0.01556213]
# cap_mae, median: [0.04854305 0.02593462 0.06060919 0.06199751], std: [0.00743061 0.00243548 0.01226397 0.01034615]
# cap_mape, median: [5.19756376 2.70697107 6.28151618 8.13875121], std: [0.80656807 0.25663571 1.27443486 1.48619683]
# life_rmse, median: [177.42374616 202.26117552 251.08520418 402.93797338], std: [13.50402502 23.04585008 11.88412166 27.18369282]
# life_mae, median: [110.66114504 119.10492717 161.93058035 273.00074846], std: [ 9.38964185 10.69579589 11.65072933 36.05261467]
# life_mape, median: [16.67074827 14.73051397 13.70407889 33.21284461], std: [1.50789214 1.79648739 1.02565509 4.46586899]

# %% [markdown]
# ### Delta QV curve

# %%
results = [('trail #4', 26.284368753433228, 0.45157551765441895, [0.2904540405815134, 0.46506977732880517, 0.35956847140650317, 0.07447714604989454], [0.17159342374978714, 0.27130577474009826, 0.21290231480793279, 0.03846421409589119], [18.024523285710146, 28.326807591680193, 22.06286000101698, 5.73847799555189], [294.15573059345274, 366.0460876160748, 417.99553659947264, 197.38174629667077], [177.45460022278343, 204.71439609818628, 325.0105771805344, 148.83562674238325], [22.663613558756886, 21.549023638937566, 28.225741034096828, 20.78337879448244]), ('trail #0', 31.291605949401855, 0.49866747856140137, [0.09132570312248606, 0.11811024269166542, 0.052661902844083265, 0.10950765925833947], [0.055197023200070396, 0.07045028102357408, 0.03231673361542691, 0.05824214765643515], [5.810158717723905, 7.358873104478603, 3.335560823922086, 8.44490068723354], [226.85742790070648, 283.9467288818958, 233.3608346533985, 747.4947867630042], [132.59322154369016, 160.67401972941911, 142.45992619966938, 665.6
264], [181.986897435161, 202.33392303781775, 303.5348446599164, 926.8607534183831], [29.512915494033585, 29.507060614220677, 31.024713702265398, 118.62745674778164]), ('trail #2', 34.67218232154846, 0.1515941619873047, [0.10029324651449918, 0.09115338042472747, 0.05880970082450868, 0.09849554316038998], [0.05951002322090331, 0.05417434037303271, 0.035892480418899614, 0.05186006938240691], [6.307242921507891, 5.667876081340302, 3.7074785099403416, 7.5443661502869395], [172.36560454389107, 227.85979783138765, 238.29941424853342, 554.3167912804985], [109.28623517739213, 140.65101219280433, 159.93577199903876, 466.6672881777844], [16.2166775686905, 17.050684763256346, 14.477621362635102, 58.81457295014086]), ('trail #6', 34.99079775810242, 0.11568665504455566, [0.0899993200303018, 0.09990902740401329, 0.06717140436760709, 0.09342791284183627], [0.05392429530613608, 0.059783926387900026, 0.04134099308150731, 0.04873747619941632], [5.690835244099709, 6.2484616390616585, 4.269864584755208, 7.160570038580037], [198.21484298189708, 252.836372229177, 249.48410806781092, 440.9362204103406], [115.84853832391816, 143.54003154890077, 153.41775131546754, 373.26595678148936], [16.476987754012086, 16.729047904801718, 13.45395452662222, 47.93751115942006])]

# %%
import numpy as np
num_trials = len(results)
num_datasets = 4
training_time, eval_time = np.full(num_trials, np.nan), np.full(num_trials, np.nan)
cap_rmse, cap_mae, cap_mape = np.full((num_trials, num_datasets), np.nan), \
                              np.full((num_trials, num_datasets), np.nan), \
                              np.full((num_trials, num_datasets), np.nan)
life_rmse, life_mae, life_mape = np.full((num_trials, num_datasets), np.nan), \
                                 np.full((num_trials, num_datasets), np.nan), \
                                 np.full((num_trials, num_datasets), np.nan)

for idx, trail in enumerate(results):
    training_time[idx], eval_time[idx] = trail[1], trail[2]
    cap_rmse[idx, :] = np.array(trail[3])
    cap_mae[idx, :] = np.array(trail[4])
    cap_mape[idx, :] = np.array(trail[5])
    life_rmse[idx, :] = np.array(trail[6])
    life_mae[idx, :] = np.array(trail[7])
    life_mape[idx, :] = np.array(trail[8])

print(f"training time, median:{np.median(training_time)}, std: {training_time.std()}")
print(f"eval time, median: {np.median(eval_time)}, std: {eval_time.std()}")
print(f"cap_rmse, median:{np.median(cap_rmse, axis=0)}, std: {cap_rmse.std(axis=0)}")
print(f"cap_mae, median: {np.median(cap_mae, axis=0)}, std: {cap_mae.std(axis=0)}")
print(f"cap_mape, median: {np.median(cap_mape, axis=0)}, std: {cap_mape.std(axis=0)}")
print(f"life_rmse, median: {np.median(life_rmse, axis=0)}, std: {life_rmse.std(axis=0)}")
print(f"life_mae, median: {np.median(life_mae, axis=0)}, std: {life_mae.std(axis=0)}")
print(f"life_mape, median: {np.median(life_mape, axis=0)}, std: {life_mape.std(axis=0)}")
# Out:
# training time, median:32.30544447898865, std: 2.4162953989482348
# eval time, median: 0.28335142135620117, std: 0.1505011769325741
# cap_rmse, median:[0.08362263 0.08870032 0.05022408 0.10526117], std: [0.06591612 0.1157103  0.0930228  0.01216253]
                              np.full((num_trials, num_datasets), np.nan), \
                              np.full((num_trials, num_datasets), np.nan)
life_rmse, life_mae, life_mape = np.full((num_trials, num_datasets), np.nan), \
                                 np.full((num_trials, num_datasets), np.nan), \
                                 np.full((num_trials, num_datasets), np.nan)
trail_idxs = np.full(num_trials, np.nan)
for idx, trail in enumerate(results):
    trail_idxs[idx] = int(trail[0].split("#")[-1])
    training_time[idx], eval_time[idx] = trail[1], trail[2]
    cap_rmse[idx, :] = np.array(trail[3])
    cap_mae[idx, :] = np.array(trail[4])
    cap_mape[idx, :] = np.array(trail[5])
    life_rmse[idx, :] = np.array(trail[6])
    life_mae[idx, :] = np.array(trail[7])
    life_mape[idx, :] = np.array(trail[8])

print(f"training time, median:{np.median(training_time)}, std: {training_time.std()}")
print(f"eval time, median: {np.median(eval_time)}, std: {eval_time.std()}")
print(f"cap_rmse, median:{np.median(cap_rmse, axis=0)}, std: {cap_rmse.std(axis=0)}")
print(f"cap_mae, median: {np.median(cap_mae, axis=0)}, std: {cap_mae.std(axis=0)}")
print(f"cap_mape, median: {np.median(cap_mape, axis=0)}, std: {cap_mape.std(axis=0)}")
print(f"life_rmse, median: {np.median(life_rmse, axis=0)}, std: {life_rmse.std(axis=0)}")
print(f"life_mae, median: {np.median(life_mae, axis=0)}, std: {life_mae.std(axis=0)}")
print(f"life_mape, median: {np.median(life_mape, axis=0)}, std: {life_mape.std(axis=0)}")
# Out:
# training time, median:21.507113456726074, std: 0.7540842552292759
# eval time, median: 0.1413125991821289, std: 0.03181810451607149
# cap_rmse, median:[0.08176781 0.0419694  0.10661609 0.10585674], std: [0.01308422 0.00437017 0.02215477 0.01556213]
# cap_mae, median: [0.04854305 0.02593462 0.06060919 0.06199751], std: [0.00743061 0.00243548 0.01226397 0.01034615]
# cap_mape, median: [5.19756376 2.70697107 6.28151618 8.13875121], std: [0.80656807 0.25663571 1.27443486 1.48619683]
# life_rmse, median: [177.42374616 202.26117552 251.08520418 402.93797338], std: [13.50402502 23.04585008 11.88412166 27.18369282]
# life_mae, median: [110.66114504 119.10492717 161.93058035 273.00074846], std: [ 9.38964185 10.69579589 11.65072933 36.05261467]
# life_mape, median: [16.67074827 14.73051397 13.70407889 33.21284461], std: [1.50789214 1.79648739 1.02565509 4.46586899]

# %%
trail_idxs
# Out:
# array([2., 5., 1., 7., 0., 3., 4., 6., 9., 8.])

# %%
cap_mae_all_data = cap_mae.mean(axis=1)
life_mape_all_data = life_mape.mean(axis=1)

# %%
np.argsort(life_mape_all_data)[len(life_mape_all_data)//2]
# Out:
# 7

# %%
cap_mae_all_data
# Out:
# array([0.05231325, 0.05135099, 0.04986803, 0.06212474, 0.04319829,
#        0.05268555, 0.03987442, 0.04377901, 0.06088077, 0.03900336])

# %%
life_mape_all_data
# Out:
# array([19.76886612, 18.73723022, 18.50993532, 17.84311295, 22.88836457,
#        20.15839589, 20.76761803, 18.52886325, 19.33247898, 23.39203294])
